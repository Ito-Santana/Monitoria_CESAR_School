# %% [markdown]
# <a href="https://colab.research.google.com/github/Ito-Santana/Monitoria_CESAR_School/blob/main/Lista_de_revis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Cópia de Desafio.png](data:image/png;base64,...)

# %% [markdown]
# ------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vetor=[]
maiores=0
menores=0
iguais=0

for i in range(10):
  numero=int(input(f"Adicione o {i+1}º inteiro: "))
  vetor.append(numero)


for i in range(1,10):
  if vetor[0]== vetor[i]:
    iguais+=1
  elif vetor[0]< vetor[i]:
    maiores+=1
  elif vetor[0] > vetor[i]:
    menores+=1

print(f'Existem {maiores} valores maiores que o 1º valor inserido')
print(f'Existem {iguais} valores iguais que o 1º valor inserido')
print(f'Existem {menores} valores menores que o 1º valor inserido')
# Out:
# Adicione o 1º inteiro: 5
# Adicione o 2º inteiro: 6
# Adicione o 3º inteiro: 7
# Adicione o 4º inteiro: 8
# Adicione o 5º inteiro: 4
# Adicione o 6º inteiro: 2
# Adicione o 7º inteiro: 1
# Adicione o 8º inteiro: 5
# Adicione o 9º inteiro: 5
# Adicione o 10º inteiro: 9
# Existem 4 valores maiores que o 1º valor inserido
# Existem 2 valores iguais que o 1º valor inserido
# Existem 3 valores menores que o 1º valor inserido

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def validar_ip(ip):
    partes = ip.split('.')
    if len(partes) != 4:
        return False

    for parte in partes:
        if not parte.isdigit() or not (0 <= int(parte) <= 255):
            return False

    return True

def ler_ips(arquivo):
    with open(arquivo, 'r') as f:
        ips = f.readlines()

    return [ip.strip() for ip in ips]

def verificar_ips(arquivo):
    ips = ler_ips(arquivo)
    for ip in ips:
        if validar_ip(ip):
            print(f"{ip} - Válido")
        else:
            print(f"{ip} - Inválido")


arquivo_ips = "enderecos_ips.txt"

verificar_ips(arquivo_ips)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-5a9f4aff302a> in <cell line: 29>()
#      27 arquivo_ips = "enderecos_ips.txt"
#      28
# ---> 29 verificar_ips(arquivo_ips)
#
# <ipython-input-16-5a9f4aff302a> in verificar_ips(arquivo)
#      17
#      18 def verificar_ips(arquivo):
# ---> 19     ips = ler_ips(arquivo)
#      20     for ip in ips:
#      21         if validar_ip(ip):
#
# <ipython-input-16-5a9f4aff302a> in ler_ips(arquivo)
#      11
#      12 def ler_ips(arquivo):
# ---> 13     with open(arquivo, 'r') as f:
#      14         ips = f.readlines()
#      15
#
# FileNotFoundError: [Errno 2] No such file or directory: 'enderecos_ips.txt'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n_apts=int(input("Quantos apartamentos foram vendidos?"))
areas=[]

for i in range(n_apts):
  area=float(input("Qual a area do {i+1}º apartamento vendido ?"))
  areas.append(area)

soma_areas=sum(areas)
max_apt=max(areas)
min_apt=min(areas)

print(f'A soma das areas dos {n_apts} apartamentos é de : {soma_areas}')
print(f'A area do maior apartamento é : {max_apt}')
print(f'A area do menor apartamento é : {min_apt}')
# Out:
# Quantos apartamentos foram vendidos?3
# Qual a area do {i+1}º apartamento vendido ?50
# Qual a area do {i+1}º apartamento vendido ?75
# Qual a area do {i+1}º apartamento vendido ?25
# A soma das areas dos 3 apartamentos é de : 150.0
# A area do maior apartamento é : 75.0
# A area do menor apartamento é : 25.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def salvar_nomes(arquivo):
    with open(arquivo, 'w') as f:
        for i in range(6):
            nome = input(f"Digite o nome e sobrenome da pessoa {i + 1}: ")
            f.write(nome + '\n')

def modificar_nomes(arquivo):
    with open(arquivo, 'r') as f:
        nomes = f.readlines()

    for i in range(len(nomes)):
        nome_atual = nomes[i].strip()
        print(f"Nome atual: {nome_atual}")
        resposta = input("Deseja alterar este nome? (Sim/Não): ").strip().lower()

        if resposta == 'sim':
            novo_nome = input("Digite o novo nome e sobrenome: ")
            nomes[i] = novo_nome + '\n'

    with open(arquivo, 'w') as f:
        f.writelines(nomes)

arquivo_nomes = "nomes.txt"
salvar_nomes(arquivo_nomes)
modificar_nomes(arquivo_nomes)
# Out:
# Digite o nome e sobrenome da pessoa 1: Italo santana
# Digite o nome e sobrenome da pessoa 2: Italo La Torre
# Digite o nome e sobrenome da pessoa 3: Pedro liberal
# Digite o nome e sobrenome da pessoa 4: Lillian Barbosa
# Digite o nome e sobrenome da pessoa 5: Pessoal x
# Digite o nome e sobrenome da pessoa 6: Ivania
# Nome atual: Italo santana
# Deseja alterar este nome? (Sim/Não): Não
# Nome atual: Italo La Torre
# Deseja alterar este nome? (Sim/Não): Não
# Nome atual: Pedro liberal
# Deseja alterar este nome? (Sim/Não): Não
# Nome atual: Lillian Barbosa
# Deseja alterar este nome? (Sim/Não): Não
# Nome atual: Pessoal x
# Deseja alterar este nome? (Sim/Não): Sim
# Digite o novo nome e sobrenome: Gabriel Silva
# Nome atual: Ivania
# Deseja alterar este nome? (Sim/Não): Sim
# Digite o novo nome e sobrenome: Ivania Santana
